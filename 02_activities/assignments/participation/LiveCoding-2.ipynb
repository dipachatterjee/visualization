# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(613)
x=np.arange(50)
y=np.random.randint(0, 100,50)

fig,ax=plt.subplots(1,1,figsize=(5, 3)) # fig and ax are variables here
fig.patch.set_facecolor("#e77e7e")

ax.patch.set_facecolor("#7ee793")
ax.tick_params(axis='both', colors='#7ee793')

# %% [markdown]
# Assignment 2:
# 2 public data visualization - good and bad
# For each visualization:
# 1) explain why you classified each graph as good/bad - use references
# 2) how you could improve (colours, labels, etc)
#
# At least 3 reasons for each classifications as good/bad
# At least 2 suggestions for improvements
#
# Just give link to the graphs
# 500 words total for the whole assignment
